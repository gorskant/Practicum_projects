# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Антон, привет!**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если это неприемлемо, то дай мне знать и мы перейдем на «вы».
#
# Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. При проверке я обращаю внимание не только на код, но и на интерпретацию и анализ результатов, а также соответствие данных техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно делаешь, что не убираешь описание задачи. Это поможет быстро вспомнить, о чем проект, если ты к нему вернешься спустя какое-то время.
#
# Данный блок можно расширить при помощи плана работы и описания данных. Посмотреть подробнее про вступительный блок можно в разделе "Полезные инструкции в учебе" блока "Оформление проекта".
#
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %% [markdown]
# #### Загрузите данные из csv-файла в датафрейм c помощью библиотеки pandas.

# %% [markdown]
# Импортируем нужные библиотеки

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Загрузим данные из CSV в дата-фрейм:

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\\t', engine='python')

data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Хорошей практикой является разделение импорта библиотек и выполнения основной логики кода, такой как загрузка данных, для лучшей читаемости и структурированности. Такое разделение помогает сделать код более понятным и удобным для других разработчиков или коллег, которые будут просматривать или использовать твой код.
#
# Разделение импортов и загрузки данных — это общепринятая хорошая практика, которой рекомендуется следовать
# </div>

# %% [markdown]
# Добавим описание данных из задания:
#
# + `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м),
# +`balcony` — число балконов
# +`ceiling_height` — высота потолков (м)
# +`cityCenters_nearest` — расстояние до центра города (м)
# +`days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# +`first_day_exposition` — дата публикации
# +`floor` — этаж
# +`floors_total` — всего этажей в доме
# +`is_apartment` — апартаменты (булев тип)
# +`kitchen_area` — площадь кухни в квадратных метрах (м²)
# +`last_price` — цена на момент снятия с публикации
# +`living_area` — жилая площадь в квадратных метрах (м²)
# +`locality_name` — название населённого пункта
# +`open_plan` — свободная планировка (булев тип)
# +`parks_around3000` — число парков в радиусе 3 км
# +`parks_nearest` — расстояние до ближайшего парка (м)
# +`ponds_around3000` — число водоёмов в радиусе 3 км
# +`ponds_nearest` — расстояние до ближайшего водоёма (м)
# +`rooms` — число комнат
# +`studio` — квартира-студия (булев тип)
# +`total_area` — общая площадь квартиры в квадратных метрах (м²)
# +`total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# #### Изучите общую информацию о полученном датафрейме

# %% [markdown]
# Начнем изучение данных дата-фрейма с применения метода `info`:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Можем сказать, что общее кол-во записей - 23699. Также видим, что в некоторых столбцах есть как пропущенные значения. Например, в столбцах `parks_nearest` и `ponds_nearest`. Применим `.describe()`:

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# В некоторых столбцах обнаружились еще и нулевые значения.

# %% [markdown]
# #### Постройте гистограмму для всех числовых столбцов таблицы на одном графике.

# %% [markdown]
# Построим гистограммы для всех числовых столбцов. Выберем столбцы с типами `int` и `float`

# %%
data.select_dtypes(include=['int', 'float']).hist(figsize=(20, 20))
# Out:
# array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Предупреждения перед графиками можно убрать одним из способов:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку matplotlib.pyplot as plt
# 2. В конец кода добавить `;`
# </div>

# %% [markdown]
# **Вывод**
#
#
# Данные загружены, данные прочитаны, данные изучены, гистограммы построены.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Хорошая вводная часть.
#
# Рекомендую создать универсальную функцию, которая будет принимать на вход датафрейм, а на выходе она будет выводить всего нужные характеристики, например, head, describe, info, дубликаты и т.п.
# </div>

# %% [markdown]
# ### Выполните предобработку данных

# %% [markdown]
# #### Найдите и изучите пропущенные значения в столбцах:

# %% [markdown]
# ##### Определите, в каких столбцах есть пропуски

# %% [markdown]
# Вот, что можно заметить:
# + `rooms` - пропущенных значений нет, но есть нулевые значения.
# + `ceiling_height` - есть неоправданно низкие и высокие значения и пропущенные данные. Скорее всего, люди просто не в курсе высоты потолков в предлагаемой ими недвижимости или допустили ошибку при вводе.
# + `first_day_exposition` - формат `object`. Нужно перевести в datetime.
# + `floors_total` - надо поменять float на int. Кол-во этажей - целое значение. Есть пропущенные значения. Пропущенные значения, возможно, вызваны тем, что пользователи не знают кол-во этажей в своих дома или они просто не парились с этим. Можно заполнить пропуски на основании удаленности здания от центра. В крупных городах, количество малоэтажек повышается по мере приближения к центру.
# + `living_area` - Есть пропущенные значения. Можно заменить медианой по площадям квартир с таким же количеством комнат в той же локации.
# + `balcony` - Есть пропущенные значения. Поменять float на int. Пропусками скорее всего отмечено отсутствие балкона.
# + `locality_name` - Есть пропущенные значения. Причина пропусков неизвестна.
# + `airports_nearest` - Есть пропущенные значения. Заполнялось системой, причина пропусков неизвестна.
# + `cityCenters_nearest` - Есть пропущенные значения. Нужно привести к змеиному языку. Заполнялось системой, причина пропусков неизвестна.
# + `parks_around3000` - Есть пропущенные значения.Заполнялось системой, причина пропусков неизвестна.
# + `parks_nearest` - Есть пропущенные значения. Заполнялось системой, причина пропусков неизвестна.
# + `ponds_around3000` - Есть пропущенные значения. Заполнялось системой, причина пропусков неизвестна.
# + `ponds_nearest` - Есть пропущенные значения. Заполнялось системой, причина пропусков неизвестна.
# + `days_exposition` - Поменять float на int. Есть пропущенные значения. Заполнялось системой, причина пропусков неизвестна.

# %% [markdown]
# ##### Заполните пропущенные значения там, где это возможно.

# %% [markdown]
# Мы не будем бороться с пропущенными значения в столбцах перечисленных ниже:
# + `rooms`
# + `airports_nearest`
# + `cityCenters_nearest`
# + `parks_around3000`
# + `parks_nearest`
# + `ponds_around3000`
# + `ponds_nearest`
#
# Причина пропусков не ясна, и подобрать какую-то закономерность не представляется возможным.

# %% [markdown]
# **`balcony`**
#
# Заменим пропущенные значения

# %%
#Заменим пропущенные значения на 0
data['balcony']=data['balcony'].fillna(0)

# %%
#Приведем к типу int
data['balcony']=data['balcony'].astype('int')
#Проверим
data['balcony'].isna().value_counts()
# Out:
# False    23699
# Name: balcony, dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, люди не заполняют "не выгодные" для продажи квартиры характеристики.
# </div>

# %% [markdown]
#  **`cityCenters_nearest`**
#
#  Переведем к "змеиному языку".

# %%
data.columns = data.columns.str.lower()

# %% [markdown]
# **`locality_name`**
#
# Заменим пропуски

# %%
data['locality_name'].isna().value_counts()
# Out:
# False    23650
# True        49
# Name: locality_name, dtype: int64

# %% [markdown]
# Неизвестно, чем могли бы быть вызваны пропущенные значения. Однако же для установки населенного пункта нам может помочь расстояние от центра. Данный датасэт говорит о Питере, поэтому можем предположить, что все квартиры с расстоянием от центра в диапазоне 15км находятся в Питере.

# %%
data['locality_name'] = data.apply(lambda row: 'Санкт-Петербург' if pd.isnull(row['locality_name']) and row['citycenters_nearest'] < 15000 else row['locality_name'], axis=1)

# %%
data['locality_name'].isna().value_counts()
# Out:
# False    23678
# True        21
# Name: locality_name, dtype: int64

# %% [markdown]
# Отлично, удалось сократить больше половины пропущенных значений. Остальные, оставлю нетронутыми, потому что не совсем представляю, как их можно закрыть. Даже зная расстояние от центра Питера до населенного пункта. Ведь населенные пункты могут быть как на западе и востоке, так и на юге и севере. А таких данных у нас нет.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Доля пропусков здесь менее 5% и мы вполне можем их удалить.
# </div>

# %% [markdown]
# **`ceiling_height`, `floors_total`**
#
# Пропущенные значения в этих столбцах можно заменить на основании территориального признака. Попробуем разделить квартиры на 3 группы по удаленности от центра. Найдем медиану для каждого из трех столбцов в этих группах. Запишем медианные значения вместо пропущенных.
# Воспользуемся методом `qcut`.

# %%
print(data['ceiling_height'].isna().value_counts())
print(data['floors_total'].isna().value_counts())
# Out:
# False    14504
# True      9195
# Name: ceiling_height, dtype: int64
# False    23613
# True        86
# Name: floors_total, dtype: int64

# %%
data['ceiling_hight_vs_center'] = pd.qcut(data[data['citycenters_nearest'] < 15000]['citycenters_nearest'], q=3)

# %%
pivot_ceiling_hight = data.pivot_table(index='ceiling_hight_vs_center', values=['ceiling_height','floors_total'], aggfunc='median')
pivot_ceiling_hight
# Out:
#                          ceiling_height  floors_total
# ceiling_hight_vs_center
# (180.999, 8370.0]                  3.00           6.0
# (8370.0, 12266.333]                2.65          10.0
# (12266.333, 14998.0]               2.60          12.0

# %% [markdown]
# Видим, что с удалением от центра, высота потолков уменьшается, а кол-во этажей увеличивается. В центрах городов обычно находятся старые постройки высотой в 5-6 этажей, а ближе к окраинам находятся человейники.
# Заполним пропуски для Питера.

# %%
'''def fill_missing_height(row):
    if pd.isnull(row['ceiling_height']):
        if row['citycenters_nearest'] <= 8370:
            return 3.00
        elif row['citycenters_nearest'] <= 12266.333:
            return 2.65
        elif row['citycenters_nearest'] <= 14998.0:
            return 2.60
    else:
        return row['ceiling_height']

data['ceiling_height'] = data.apply(fill_missing_height, axis=1)

def fill_missing_floors(row):
    if pd.isnull(row['floors_total']):
        if row['citycenters_nearest'] <= 8370:
            return 6.0
        elif row['citycenters_nearest'] <= 12266.333:
            return 10.0
        elif row['citycenters_nearest'] <= 14998.0:
            return 12.0
    else:
        return row['floors_total']

data['floors_total'] = data.apply(fill_missing_floors, axis=1)

print(data['ceiling_height'].isna().value_counts())
print(data['floors_total'].isna().value_counts())'''
# Out:
# "def fill_missing_height(row):\n    if pd.isnull(row['ceiling_height']):\n        if row['citycenters_nearest'] <= 8370:\n            return 3.00\n        elif row['citycenters_nearest'] <= 12266.333:\n            return 2.65\n        elif row['citycenters_nearest'] <= 14998.0:\n            return 2.60\n    else:\n        return row['ceiling_height']\n\ndata['ceiling_height'] = data.apply(fill_missing_height, axis=1)\n\ndef fill_missing_floors(row):\n    if pd.isnull(row['floors_total']):\n        if row['citycenters_nearest'] <= 8370:\n            return 6.0\n        elif row['citycenters_nearest'] <= 12266.333:\n            return 10.0\n        elif row['citycenters_nearest'] <= 14998.0:\n            return 12.0\n    else:\n        return row['floors_total']\n\ndata['floors_total'] = data.apply(fill_missing_floors, axis=1)\n\nprint(data['ceiling_height'].isna().value_counts())\nprint(data['floors_total'].isna().value_counts())"

# %% [markdown]
# Число пропусков в `ceiling_height` и `floors_total` удалось сократить в два раза. Остались пропущенные значения для посёлков и пгт. Пропуски можно заменить, если известно название населенного пункта. С остальными ничего не сделать. Сначала надо привести посЁлки к посЕлкам или наоборот.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# ceiling_height - Высоту можно заполнить медианой с учетом группировки по локации или расстоянию до центра в км, логично что в большинстве случаев потолки в исторической застройке выше. Либо же как вариант заполнить медианой.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# floors_total - также можно удалить пропуски за малой долей.
# </div>

# %%
def fill_median_by_group (df, column, groupby_column):
    filled_column = df[column].fillna(df.groupby(groupby_column)[column].transform('median'))
    df[column]=filled_column

# %%
fill_median_by_group(data,'floors_total', 'citycenters_nearest')
fill_median_by_group(data,'ceiling_height', 'citycenters_nearest')
print(data['ceiling_height'].isna().value_counts())
print(data['floors_total'].isna().value_counts())
# Out:
# False    18950
# True      4749
# Name: ceiling_height, dtype: int64
# False    23680
# True        19
# Name: floors_total, dtype: int64

# %% [markdown]
# UPD: Среднее заменено не медиану в версии v.1
# Добавлено решение с группировкой по расстоянию до центра.

# %%
data['locality_name'] = data['locality_name'].str.replace('посёлок', 'поселок')
data['locality_name']
# Out:
# 0            Санкт-Петербург
# 1             поселок Шушары
# 2            Санкт-Петербург
# 3            Санкт-Петербург
# 4            Санкт-Петербург
#                 ...
# 23694        Санкт-Петербург
# 23695                  Тосно
# 23696       село Рождествено
# 23697        Санкт-Петербург
# 23698    поселок Новый Учхоз
# Name: locality_name, Length: 23699, dtype: object

# %% [markdown]
# Заполним пропуски в `ceiling_height` и `floors_total` средним значением сгруппированным по населенным пунктам.

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data.query('locality_name != "Санкт-Петербург"').groupby('locality_name')['ceiling_height'].transform('median'))
data['floors_total'] = data['floors_total'].fillna(data.query('locality_name != "Санкт-Петербург"').groupby('locality_name')['floors_total'].transform('median'))

data.dropna(subset=['floors_total'],inplace=True)

print(data['ceiling_height'].isna().value_counts())
print(data['floors_total'].isna().value_counts())
# Out:
# False    21835
# True      1856
# Name: ceiling_height, dtype: int64
# False    23691
# Name: floors_total, dtype: int64

# %% [markdown]
# Удалось сократить число пропущенных значений почти в два раза.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# До обработки выбросов не стоит заполнять пропуски средним арифметическим. После обработки пропусков - это допустимо. Но, проще всего высоту заполнить медианой, как я и писал выше.
#
# floors_total - также не следует заполнять средним значением. Велика вероятность исказить данные.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# **`last_price`**

# %% [markdown]
# Переведем к `int`

# %%
data['last_price'] = data['last_price'].astype('int')
data['last_price']
# Out:
# 0        13000000
# 1         3350000
# 2         5196000
# 3        64900000
# 4        10000000
#            ...
# 23694     9700000
# 23695     3100000
# 23696     2500000
# 23697    11475000
# 23698     1350000
# Name: last_price, Length: 23691, dtype: int64

# %% [markdown]
# **`is_apartment`**
#
# Заполним пропуски `False`

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)
data['is_apartment']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23694    False
# 23695    False
# 23696    False
# 23697    False
# 23698    False
# Name: is_apartment, Length: 23691, dtype: bool

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Все верно, либо это апартаменты, либо нет. Булев тип подходит лучше всего.
# </div>

# %% [markdown]
# **`first_day_exposition`**
#
# Переведем к `datetime`

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d')
data['first_day_exposition']
# Out:
# 0       2019-03-07
# 1       2018-12-04
# 2       2015-08-20
# 3       2015-07-24
# 4       2018-06-19
#            ...
# 23694   2017-03-21
# 23695   2018-01-15
# 23696   2018-02-11
# 23697   2017-03-28
# 23698   2017-07-21
# Name: first_day_exposition, Length: 23691, dtype: datetime64[ns]

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 При чтении файла можно указать параметр `parse_dates: parse_dates=['date']`. Тогда пандас автоматически переведет список столбцов в даты. Пример можно посмотреть [здесь](https://newtechaudit.ru/gruzi-daty-krasivo/).
# </div>

# %% [markdown]
# Похоже, что это все, что можно было сделать на данном этапе. И так, что у нас получилось:
# * `balcony` - заменили пропущенные значения на 0.
# * `cityCenters_nearest` - приведен к змеиному языку
# * `locality_name` - заполнены пропуски, значения приведены к общей структуре.
# * `ceiling_height`- заполнены пропуски
# * `floors_total`- заполнены пропуски
# * `last_price` - переведено к int
# * `is_apartment` - заполнены пропуски
# * `first_day_exposition` - переведено к datetime

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# В целом не плохое заполнение.
# </div>

# %% [markdown]
# #### Рассмотрите типы данных в каждом столбце:
#
# ###### Найдите столбцы, в которых нужно изменить тип данных. Преобразуйте тип данных в выбранных столбцах.

# %%
dlya_int = ['last_price', 'floors_total', 'balcony', 'airports_nearest', 'citycenters_nearest', 'parks_around3000',
               'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'days_exposition']

for column in dlya_int:
    data[column] = np.floor(pd.to_numeric(data[column], errors='coerce')).astype('Int64')

dlya_float = ['total_area', 'ceiling_height', 'living_area', 'kitchen_area']
    
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23691 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   total_images             23691 non-null  int64
#  1   last_price               23691 non-null  Int64
#  2   total_area               23691 non-null  float64
#  3   first_day_exposition     23691 non-null  datetime64[ns]
#  4   rooms                    23691 non-null  int64
#  5   ceiling_height           21835 non-null  float64
#  6   floors_total             23691 non-null  Int64
#  7   living_area              21791 non-null  float64
#  8   floor                    23691 non-null  int64
#  9   is_apartment             23691 non-null  bool
#  10  studio                   23691 non-null  bool
#  11  open_plan                23691 non-null  bool
#  12  kitchen_area             21416 non-null  float64
#  13  balcony                  23691 non-null  Int64
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Обрати, пожалуйста, внимание на тип данных в floors_total, вряд ли он должен быть дробным.
# </div>

# %% [markdown]
# Все, что нужно, поменялось в int64.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ##### Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты.

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'поселок Шушары', 'городской поселок Янино-1',
#        'поселок Парголово', 'поселок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'поселок Металлострой',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок городского типа Ефимовский', 'поселок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
# ...

# %%
data.duplicated().value_counts()
# Out:
# False    23691
# dtype: int64

# %%
data['locality_name'] = data['locality_name'].replace(['поселок городского типа', 'городской поселок', 'поселок станции', 'поселок при железнодорожной станции', 'коттеджный поселок'], 'поселок', regex=True)
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000      108.00           2019-03-07      3
# 1              7     3350000       40.40           2018-12-04      1
# 2             10     5196000       56.00           2015-08-20      2
# 3              0    64900000      159.00           2015-07-24      3
# 4              2    10000000      100.00           2018-06-19      2
# 5             10     2890000       30.40           2018-09-10      1
# 6              6     3700000       37.30           2017-11-02      1
# 7              5     7915000       71.60           2019-04-18      2
# 8             20     2900000       33.16           2018-05-23      1
# 9             18     5400000       61.00           2017-02-26      3
# 10             5     5050000       39.60           2017-11-16      1
# 11             9     3300000       44.00           2018-08-27      2
# 12            10     3890000       54.00           2016-06-30      2
# ...

# %%
data['locality_name'].value_counts().sort_values(ascending=False).head(40)
# Out:
# Санкт-Петербург            15742
# поселок Мурино               556
# поселок Шушары               440
# Всеволожск                   398
# Пушкин                       369
# Колпино                      338
# поселок Парголово            327
# Гатчина                      307
# деревня Кудрово              299
# Выборг                       237
# Петергоф                     201
# Сестрорецк                   183
# Красное Село                 178
# Кудрово                      173
# деревня Новое Девяткино      144
# Сертолово                    142
# Ломоносов                    133
# Кириши                       125
# поселок Бугры                114
# Сланцы                       112
# Волхов                       111
# Кингисепп                    104
# Тосно                        104
# Кронштадт                     96
# Никольское                    93
# Коммунар                      89
# Сосновый Бор                  87
# Кировск                       84
# ...

# %%
data[data['locality_name'].duplicated(keep=False)]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 3                 0    64900000      159.00           2015-07-24      3
# 4                 2    10000000      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
#Код ниже помог найти почти одинаковые пары слов. Например Мурино и поселок Мурино. Я закомментил его, чтобы не перегружать ядро. 
#Все равно от работы этого кода структура данных не меняется.

'''from fuzzywuzzy import fuzz

threshold = 100 # пороговое значение для сравнения
duplicates = []

for name in data['locality_name'].unique():
    if pd.notnull(name):  # Проверяем на пропуск
        for other_name in data['locality_name'].unique():
            if name != other_name and pd.notnull(other_name) and fuzz.partial_ratio(name, other_name) >= threshold:
                duplicates.append((name, other_name))
            
duplicates'''
# Out:
# "from fuzzywuzzy import fuzz\n\nthreshold = 100 # пороговое значение для сравнения\nduplicates = []\n\nfor name in data['locality_name'].unique():\n    if pd.notnull(name):  # Проверяем на пропуск\n        for other_name in data['locality_name'].unique():\n            if name != other_name and pd.notnull(other_name) and fuzz.partial_ratio(name, other_name) >= threshold:\n                duplicates.append((name, other_name))\n            \nduplicates"

# %%
#Подставляем совпавшие значения, чтобы осталось только одно.
names_to_replace=['Мурино','Кудрово','Никольское', 'Любань']
replace_with_names=['поселок Мурино','деревня Кудрово','село Никольское','поселок Любань']
data['locality_name'] = data['locality_name'].replace(names_to_replace,replace_with_names)
data['locality_name'].value_counts().sort_values(ascending=False).head(40)
# Out:
# Санкт-Петербург            15742
# поселок Мурино               590
# деревня Кудрово              472
# поселок Шушары               440
# Всеволожск                   398
# Пушкин                       369
# Колпино                      338
# поселок Парголово            327
# Гатчина                      307
# Выборг                       237
# Петергоф                     201
# Сестрорецк                   183
# Красное Село                 178
# деревня Новое Девяткино      144
# Сертолово                    142
# Ломоносов                    133
# Кириши                       125
# поселок Бугры                114
# Сланцы                       112
# Волхов                       111
# Кингисепп                    104
# Тосно                        104
# Кронштадт                     96
# село Никольское               94
# Коммунар                      89
# Сосновый Бор                  87
# Кировск                       84
# Отрадное                      80
# ...

# %% [markdown]
# **Вывод**
#
# Неявные дубликаты устранены.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Можно еще применить такой подход:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# К сожалению мы не посмотрели наличие явных дубликатов в датасете, а это основа предобработки данных.
# </div>

# %%
print(data['locality_name'].duplicated().value_counts())
# Out:
# True     23375
# False      316
# Name: locality_name, dtype: int64

# %% [markdown]
# Такое количество дубликатов объясняется тем, что на продажу выставлены несколько объектов в одной локации. Не будем их трогать.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 📝
# Только речь шла о датасете в целом, а не отдельном столбце. Но суть ты понял.
# </div>

# %% [markdown]
# **Вывод**
#
# Явные и неявные дубликаты установлены.

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %% [markdown]
# #### Цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой)

# %%
data['price_per_sq_m'] = data['last_price'] / data['total_area']
data['price_per_sq_m'] = data['price_per_sq_m'].astype('int')

# %% [markdown]
# #### День, месяц и год недели публикации объявления

# %%
data['weekday_exposition'] = data['first_day_exposition'].dt.weekday
data['month_exposition'] = data['first_day_exposition'].dt.month
data['year_exposition'] = data['first_day_exposition'].dt.year

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# На будущее: часто датафреймы содержат данные за разные годы. Чтобы корректно обработать месяцы и не объединить их из разных годов, можно рассмотреть такой метод `astype('datetime64[M]')`. При использовании этого метода не придется ссылаться на `pd.DatetimeIndex`.
#
# Рекомендую ознакомиться с этими материалами:
#
# [Работа с датами в Python]( https://pythobyte.com/how-to-work-with-dates-and-times-in-python-0a176355/)
#
# [Извлечение часов, минут и секунд из numpy datetime64](https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64)
#
# Попробуй использовать этот метод, когда агализируешь динамику по неделям, месяцам или годам.
#
# Пример применения:
#
#
# `df['first_day_exposition'].dt.date # конвертация в формат даты
# df['first_day_exposition'].astype('datetime64[M]')`
#
# Если даты в датафрейме из разных годов, то после преобразования месяцы будут отображаться как первый день каждого месяца, например '2019-05-01'.
#
# </div>

# %% [markdown]
# #### Тип этажа квартиры (значения — «‎первый», «последний», «другой»)

# %%
def floor_category(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    elif 1 < floor < floors_total:
        return 'другой'
    
data['floor_category'] = data.apply(floor_category, axis = 1)

# %% [markdown]
# #### Расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений)

# %%
data['citycenters_nearest_km'] = (data['citycenters_nearest'] / 1000).astype(float).round()

# %% [markdown]
# **Вывод**
#
# Новые столбцы добавлены.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Отлично! Можем приступать к исследовательскому анализу.
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучите перечисленные ниже параметры объектов и постройте отдельные гистограммы для каждого из этих параметров. В некоторых параметрах встречаются редкие и выбивающиеся значения. При построении гистограмм удалите их.

# %% [markdown]
# Изучите параметры:
# + общая площадь;
# + жилая площадь;
# + площадь кухни;
# + цена объекта;
# + количество комнат;
# + высота потолков;
# + тип этажа квартиры («первый», «последний», «другой»);
# + общее количество этажей в доме;
# + расстояние до центра города в метрах;
# + расстояние до ближайшего паркаz

# %% [markdown]
# ##### Общая площадь

# %%
plt.figure(figsize=(10, 5))
plt.hist(data['total_area'], bins=range(0, 300, 5))  # Устанавливаем шаг сетки в 10 кв.м.
plt.xticks(range(0, 300, 15))
plt.grid(True)  # Включаем сетку
plt.xlabel('Общая площадь квартиры в м.кв.')
plt.ylabel('Кол-во объявлений')
plt.title('Объявлени по общей площади')
plt.show()
data['total_area'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_48/1726053035.py in <module>
# ----> 1 plt.figure(figsize=(10, 5))
#       2 plt.hist(data['total_area'], bins=range(0, 300, 5))  # Устанавливаем шаг сетки в 10 кв.м.
#       3 plt.xticks(range(0, 300, 15))
#       4 plt.grid(True)  # Включаем сетку
#       5 plt.xlabel('Общая площадь квартиры в м.кв.')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Обрати, пожалуйста, внимание на оформление графиков в проекте. Важно, чтобы у каждого графика было название, а оси были четко подписаны. Пожалуйста, пройдись по всем графикам и убедись в их корректном оформлении.
#
# Помни, график — это инструмент общения с заказчиком. Он должен быть ясным, лаконичным и информативным.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Отлично! Осталось только озаглавить все графики.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# Видим пиковое значение около 45кв.м. Распределение данных нормальное, есть выбросы но они не сильно влияют на данные.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, с большей площадью меньше предложений. Объекты выше 90-100 кв. м - это более дорогой сегмент.
# </div>

# %% [markdown]
# ##### Жилая площадь

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['living_area'], bins=range(0, 200, 5))  # Устанавливаем шаг сетки в 5 кв.м.
plt.xticks(range(0, 200, 10))
plt.grid(True)  # Включаем сетку
plt.xlabel('Жилая площадь квартиры в м.кв.')
plt.ylabel('Кол-во объявлений')
plt.title('Объявлени по жилой площади')
plt.show()
data['living_area'].describe()
# Out:
# count    21791.000000
# mean        34.457251
# std         22.030848
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Видим пиковое значение около 15кв.м. Распределение данных нормальное, есть выбросы но они не сильно влияют на данные.

# %% [markdown]
# ##### Площадь кухни

# %%
plt.figure(figsize=(10, 8))
plt.hist(data['kitchen_area'], bins=range(0, 60, 5))  # Устанавливаем шаг сетки в 5 кв.м.
plt.xticks(range(0, 60, 5))
plt.grid(True)  # Включаем сетку
plt.xlabel('Площадь кухни в м.кв.')
plt.ylabel('Кол-во объявлений')
plt.title('Объявлени по площади кухни')
plt.show()
data['kitchen_area'].describe()
# Out:
# count    21416.000000
# mean        10.569424
# std          5.905876
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Видим пиковое значение около 7,5кв.м. Распределение данных нормальное, есть выбросы но они не сильно влияют на данные. Большие площади кухонь, можно объяснить их совмещенностью с залом, например, а маленькие - квартирами-студиями.

# %% [markdown]
# ##### Цена объекта

# %%
plt.figure(figsize=(20, 6))
plt.hist(data['last_price'], bins=range(0, 15000000, 100000))  # Устанавливаем шаг сетки в 100000 руб.
plt.xticks(range(0, 15000000, 1000000))
plt.grid(True)  # Включаем сетку
plt.xlabel('Цена квартиры в десятках млн. руб.')
plt.ylabel('Кол-во объявлений')
plt.title('Объявлени по цене объекта')
plt.show()
data['last_price'].describe()
# Out:
# count    2.369100e+04
# mean     6.541473e+06
# std      1.088871e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.799500e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Видим пиковое значение около 4 миллионов. Распределение данных нормальное, есть выбросы но они не сильно влияют на данные.

# %% [markdown]
# ##### Высота потолков

# %%
plt.figure(figsize=(20, 10))
plt.hist(data['ceiling_height'], bins=range(1, 100, 1))  # Устанавливаем шаг сетки в 1м.
plt.xticks(range(1, 100, 1))
plt.grid(True)  # Включаем сетку
plt.xlabel('Высота потолка в м.')
plt.ylabel('Кол-во объявлений')
plt.title('Объявлени по высоте потолков')
plt.show()
data['ceiling_height'].describe()
# Out:
# count    21835.000000
# mean         2.749255
# std          1.104899
# min          1.000000
# 25%          2.550000
# 50%          2.650000
# 75%          2.760000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Очень странно, что не гистограмма не показывает занчения выше 5 метров. Построим ящик с усами.

# %%
plt.figure(figsize=(20, 4))
plt.boxplot(data['ceiling_height'].dropna(), vert=False)
plt.xticks(range(0, 100, 1))
plt.xlim(5,100)
plt.grid()
plt.xlabel('Высота потолка в м.')
plt.title('Объявлени по высоте потолков')
plt.show()

# %% [markdown]
# Значения больше 20 могут быть ошибкой при вводе данных. Посмотрим сколько их у нас вообще.

# %%
data.query('ceiling_height > 20').value_counts(data['ceiling_height'])
# Out:
# ceiling_height
# 27.0     11
# 25.0      8
# 22.6      2
# 32.0      2
# 24.0      1
# 26.0      1
# 27.5      1
# 100.0     1
# dtype: int64

# %% [markdown]
# Уберем эти значения разделив еще на 10.

# %%
data['ceiling_height'] = data['ceiling_height'].apply(lambda x: x / 10 if x >= 20 else x)

plt.figure(figsize=(10, 4))
plt.boxplot(data['ceiling_height'].dropna(), vert=False)
plt.xticks(range(0, 15, 1))
plt.xlim(0,15)
plt.grid()
plt.xlabel('Высота потолка в м.')
plt.title('Объявлени по высоте потолков')
plt.show()

data['ceiling_height'].describe()
# Out:
# count    21835.000000
# mean         2.716128
# std          0.331297
# min          1.000000
# 25%          2.550000
# 50%          2.650000
# 75%          2.750000
# max         15.125000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Со значениями меньше ничего сделать не получится, ибо логика не ясна.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично
# </div>

# %% [markdown]
# ##### Тип этажа квартиры

# %%
data['floor_category'].describe()

pd.Series(data['floor_category']).hist().set_xlabel('Категория этажа')
plt.title('Объявлени по категориям этажей')
plt.show()

# %% [markdown]
# Все выглядит нормальным.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# А какой вывод мы можем сделать исходя из графика для заказчика? Например, зависит ли продажа квартир от категорий этажей и т.д.
# </div>

# %% [markdown]
# Можем сказать, что меньше всего объявлений с квартирами расположенном на первом и последним этажах.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Да, чаще всего продают не последний и не первый этажи - такие этажи могут быть проблемными (заглядывают прохожие, холодно, жарко, протекает крыша и т.д.)
#
# Также это связано с этажностью строительства. Первый и последний этажи - это лишь по одному этажу, а группа "другой" включает в себя все этажи, кроме первого и последнего. Для 3-этажных домов мы бы увидели равномерное распределение, но строительство заметно выше, чем 3 этажа.
# </div>

# %% [markdown]
# ##### Общее количество этажей в доме

# %%
print(data['floors_total'].describe())

pd.Series(data['floors_total']).hist()
plt.xlabel('Общее количество этажей в доме')
plt.ylabel('Кол-во объявлений')
plt.title('Количество этажей в доме')
plt.show()
# Out:
# count    23691.000000
# mean        10.692837
# std          6.607106
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Все выглядит нормальным.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Аналогично
# </div>

# %% [markdown]
# Можем сказать, что больше всего предложений в объектах с количеством этажей до 10.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ##### Расстояние до центра города в метрах

# %%
print(data['citycenters_nearest'].describe())

pd.Series(data['citycenters_nearest']).hist()
plt.xlabel('Расстояние до центра города в метрах')
plt.ylabel('Кол-во объявлений')
plt.title('Расстояние до центра города')
plt.show()
# Out:
# count    18173.000000
# mean     14190.564849
# std       8608.605882
# min        181.000000
# 25%       9238.000000
# 50%      13095.000000
# 75%      16293.000000
# max      65968.000000
# Name: citycenters_nearest, dtype: float64

# %% [markdown]
# Все выглядит нормальным.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Аналогично
# </div>

# %% [markdown]
# Можем сказать, что больше всего предложений в объектах в пределах 20000м от центра.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ##### Расстояние до ближайшего парка

# %%
print(data['parks_nearest'].describe())
pd.Series(data['parks_nearest']).hist()
plt.xlabel('Расстояние до ближайшего парка метрах')
plt.ylabel('Кол-во объявлений')
plt.show()
# Out:
# count    8077.000000
# mean      490.840040
# std       342.352676
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Видим пиковое значение около 500м. Распределение данных нормальное, есть выбросы но они не сильно влияют на данные.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Отсутствуют визуализация и вывод по параметру: количество комнат
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# К сожалению визуализация и вывод не появились.
# </div>

# %% [markdown]
# Не совсем понимаю, в чем проблема. Код работает и гистограмма тоже показывается. На всякий случай дублирую код с выводом и графиком и прикладываю скрин.
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# ✍
# Антон, в моем комментарии v1 написано, какого именно параметра не хватает в исследовательской части ![image-2.png](attachment:image-2.png).
#
#
# Визуализацию по параметру `Расстояние до ближайшего парка` я увидел при первой итерации проверки и к ней вопросов нет.
#
# Прошу тебя дополнить и проект может быть принят.
#
#
#
# </div>

# %% [markdown]
# Прошу прощения, сейчас все исправлю. Код ниже:

# %%
plt.figure(figsize=(5, 5))
plt.hist(data['rooms'], bins=range(1, 10, 1))  # Устанавливаем шаг сетки в 10 кв.м.
plt.xticks(range(0, 10, 1))
plt.grid(True)  # Включаем сетку
plt.xlabel('Количество комнат')
plt.ylabel('Кол-во объявлений')
plt.title('Объявления по количеству комнат')
plt.show()
data['rooms'].describe()
# Out:
# count    23691.000000
# mean         2.070491
# std          1.078245
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# На гистограмме видно, что больше всего в продаже однокомнатных и двухкомнатных квартир. Большое кол-во комнат скорее более характерно для старого жилищного фонда или для частных домов.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.4</b>
#
# 👍Верно, однокомнатные популярней по ряду причин: цена(доступней для одиноких людей, а также людям в гражданском браке), рентабельность(покупка с целью продать дороже, а так же сдача в наём для приезжих, студентов и т.д), наследство.
# </div>

# %% [markdown]
# #### Изучите, как быстро продавались квартиры (столбец days_exposition).

# %%
plt.figure(figsize=(20, 4))
data['days_exposition'].hist(bins=150)
plt.xticks(range(0, 1600, 50))
plt.xlabel('Дни, когда объявление было активно')
plt.ylabel('Кол-во объявлений')
plt.title('Скорость продажи квартир')
plt.show()

# %%
data.boxplot(column='days_exposition')
plt.ylabel('Кол-во объявлений')
plt.title('Скорость продажи квартир')
plt.show()

# %%
#среднее значение, медиана и межквартильный размах
data['days_exposition'].describe()
# Out:
# count    20512.00000
# mean       180.90391
# std        219.73786
# min          1.00000
# 25%         45.00000
# 50%         95.00000
# 75%        232.00000
# max       1580.00000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Построим гистограмму для данных без выбросов.

# %%
plt.figure(figsize=(20, 3))
data['days_exposition'].hist(bins=150, range=(0,550))  # Устанавливаем шаг сетки в 5 дней.
plt.xticks(range(0, 550, 10))
plt.grid(True)
plt.xlabel('Дни, когда объявление было активно')
plt.ylabel('Кол-во объявлений')
plt.title('Скорость продажи квартир')
plt.show()

# %% [markdown]
# Видим пики в 45, 60 и 90 дней. Скорее всего, объявления, которые не были активны после данного срока автоматически снимаются. Уберем эти значения из выборки.

# %%
data = data.drop(data[data['days_exposition'].isin([45, 60, 90])].index)
plt.figure(figsize=(20, 5))
data['days_exposition'].hist(bins=150, range=(0,550))
plt.xticks(range(0, 550, 10))
plt.grid(True)
plt.xlabel('Дни, когда объявление было активно')
plt.ylabel('Кол-во объявлений')
plt.title('Скорость продажи квартир')
plt.show()

# %%
print(data.boxplot(column='days_exposition'))

data['days_exposition'].describe()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# count    18890.000000
# mean       191.660191
# std        225.719233
# min          1.000000
# 25%         41.000000
# 50%        110.000000
# 75%        252.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Можно сделать вывод, что чаще всего продажа квартиры происходит в срок от 41 дня до 252 дней. Быстрой продажей можно считать квартиры проданные до 41 дня после времени размещения.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верно
# </div>

# %% [markdown]
# #### Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта.**
#
# ##### Изучите, зависит ли цена от: общей площади; жилой площади; площади кухни; количества комнат; этажа, на котором расположена квартира (первый, последний, другой);даты размещения (день недели, месяц, год).

# %% [markdown]
# ###### Зависит ли цена от общей площади

# %%
'''pivot_table_total_area = data.pivot_table(index = 'total_area', values = 'price_per_sq_m', aggfunc = ['mean', 'count', 'median'])
pivot_table_total_area.columns = ['mean', 'count', 'median']
pivot_table_total_area.plot(y = 'median', style = 'o')

data['total_area'].corr(data['price_per_sq_m'])'''
# Out:
# "pivot_table_total_area = data.pivot_table(index = 'total_area', values = 'price_per_sq_m', aggfunc = ['mean', 'count', 'median'])\npivot_table_total_area.columns = ['mean', 'count', 'median']\npivot_table_total_area.plot(y = 'median', style = 'o')\n\ndata['total_area'].corr(data['price_per_sq_m'])"

# %% [markdown]
# Коэффицент корреляции низкий. Зависимость слабая.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Обрати, пожалуйста, внимание, что в ТЗ нас просят определите факторы, которые больше всего влияют на **общую (полную)** стоимость объекта, а не за квм. Это касается всех параметров.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
pivot_table_total_area_price = data.pivot_table(index = 'total_area', values = 'last_price', aggfunc = ['median'])
pivot_table_total_area_price.columns = ['median']
pivot_table_total_area_price.plot(y = 'median', style = 'o')
plt.title('Зависимость цены от общей площади')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# При попытке посчитать коэфициент Пирсона выдает ошибку - 'float' object has no attribute 'shape'.
# На графике видно небольшую корреляцию примерно 0.5-0.6, что говорит о низкой зависимости.

# %% [markdown]
# ###### Зависит ли цена от жилой площади

# %%
pivot_table_living_area_total = data.pivot_table(index = 'living_area', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_living_area_total.columns = ['mean', 'count', 'median']
pivot_table_living_area_total.plot(y = 'median', style = 'o')
plt.title('Зависимость цены от жилой площади')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# При попытке посчитать коэфициент Пирсона выдает ошибку - 'float' object has no attribute 'shape'.
# На графике видно небольшую корреляцию примерно 0.2-0.3, что говорит о низкой зависимости.

# %% [markdown]
# ###### Зависит ли цена от площади кухни

# %%
pivot_table_kitchen_area_total = data.pivot_table(index = 'kitchen_area', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_kitchen_area_total.columns = ['mean', 'count', 'median']
pivot_table_kitchen_area_total.plot(y = 'median', style = 'o')
plt.title('Зависимость цены от площади кухни')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# При попытке посчитать коэфициент Пирсона выдает ошибку - 'float' object has no attribute 'shape'.
# На графике видно небольшую корреляцию примерно 0.2-0.3, что говорит о низкой зависимости.

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# К сожалению, я не смог установить причину ошибки 'float' object has no attribute 'shape' при попытке получить числовое значение коэфицента корреляции Пирсона. Вот пример - data['total_area'].corr(data['last_price']). Возможно, дело в пропусках.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 📝
# Их можно посчитать отдельно
# </div>

# %%
# Код ревьюера
data[['last_price', 'total_area', 'living_area', 'kitchen_area', 'rooms']].corr()
# Out:
#               last_price  total_area  living_area  kitchen_area     rooms
# last_price      1.000000    0.653928     0.568339      0.520387  0.364155
# total_area      0.653928    1.000000     0.939887      0.609534  0.759509
# living_area     0.568339    0.939887     1.000000      0.430446  0.845757
# kitchen_area    0.520387    0.609534     0.430446      1.000000  0.271600
# rooms           0.364155    0.759509     0.845757      0.271600  1.000000

# %% [markdown]
# ###### Зависит ли цена от количества комнат

# %%
pivot_table_rooms = data.pivot_table(index = 'rooms', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_rooms.columns = ['mean', 'count', 'median']

print(pivot_table_rooms)

pivot_table_rooms.plot(y = 'median', style = 'o')
plt.title('Зависимость цены от от количества комнат')
plt.show
# Out:
#                   mean  count       median
# rooms
# 0        3000457.18232    181    2700000.0
# 1       3852281.613776   7462    3600000.0
# 2       5633256.794673   7359    4800000.0
# 3       8246090.538151   5452    6200000.0
# 4      13478550.714286   1120    9050000.0
# 5      23840801.175325    308   14000000.0
# 6          32530109.24    100   19250000.0
# 7      52547966.245614     57   25000000.0
# 8      50224166.666667     12   23095000.0
# 9           36602700.0      7   24000000.0
# 10     26166666.666667      3   23000000.0
# 11          25250000.0      2   25250000.0
# 12         420000000.0      1  420000000.0
# 14          26829500.0      2   26829500.0
# 15          65000000.0      1   65000000.0
# 16          28500000.0      1   28500000.0
# 19          32250000.0      1   32250000.0
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Диграмма рассеяния не очень подходит. Построим просто график для самых частых случаев (count > 12)

# %%
pivot_table_rooms.query('count > 12').plot(y = 'median')
plt.title('Зависимость цены от количества комнат')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Видим, что цена растет с ростом количества комнат. Самыми дешевыми квартирами являются однокомнантные. Ожидаемо.

# %% [markdown]
# ###### Зависит ли цена от этажа, на котором расположена квартира (первый, последний, другой)

# %%
pivot_table_floor_category = data.pivot_table(index = 'floor_category', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_floor_category.columns = ['mean', 'count', 'median']
pivot_table_floor_category.plot(y = 'median')
pivot_table_floor_category
plt.title('Зависимость цены от этажа, на котором расположена квартира')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Квартиры на первом этаже дешевле, чем на любом другом, а на последенем дороже, чем на первом, но дешевле, чем на других.

# %% [markdown]
# ###### Зависит ли цена от даты размещения (день недели, месяц, год)

# %%
#День недели
pivot_table_weekday_exposition = data.pivot_table(index = 'weekday_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_weekday_exposition.columns = ['mean', 'count', 'median']
#Месяц
pivot_table_month_exposition = data.pivot_table(index = 'month_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_month_exposition.columns = ['mean', 'count', 'median']
#Год
pivot_table_year_exposition = data.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_year_exposition.columns = ['mean', 'count', 'median']

# %%
#Вывод таблиц
print(pivot_table_weekday_exposition.sort_values('median',ascending=False))
print()
print(pivot_table_month_exposition.sort_values('median',ascending=False))
print()
print(pivot_table_year_exposition.sort_values('median',ascending=False))
# Out:
#                               mean  count     median
# weekday_exposition
# 2                   6730594.868542   3697  4800000.0
# 1                   6456959.211882   3922  4772500.0
# 0                   6628600.659769   3383  4700000.0
# 3                   6769571.274802   4032  4700000.0
# 4                   6422867.900696   3736  4600000.0
# 5                    7013025.03916   1762  4555000.0
# 6                   6308836.508783   1537  4550000.0
#
#                             mean  count     median
# month_exposition
# 4                  6763039.00784   2296  4800000.0
# 2                 6625778.744822   2414  4750000.0
# 9                 6922926.690821   1863  4740000.0
# 1                 6900635.671609   1349  4720000.0
# 3                 6393206.274101   2448  4700000.0
# 12                7056096.336307   1457  4700000.0
# 11                6410512.492617   2235  4690000.0
# 5                 6722721.549618   1179  4650000.0
# ...

# %%
#Вывод графиков
pivot_table_weekday_exposition.plot(y = 'median')
plt.title('Зависимость цены от дня объявления')
plt.show

pivot_table_month_exposition.plot(y = 'median')
plt.title('Зависимость цены от месяца объявления')
plt.show

pivot_table_year_exposition.plot(y = 'median')
plt.title('Зависимость цены от года объявления')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Вывод**
#
# Что заметно на графиках:
# + Цена квартир выставленных на продажу в течении рабочей недели выше, чем на выходных. Особенно во вторник. Это может быть связано тем, что продавцы могут быть более активны в размещении объявлений и организации показов квартир. Это может повышать видимость объявлений и привлекать больше покупателей, что в свою очередь может повлиять на цены. Некоторые продавцы могут специально выбирать рабочие дни для выставления своих квартир на продажу, чтобы привлечь больше внимания и получить лучшие предложения.
#
#
# + Ниже всего цены на квартиры становятся в Июне, а самые высокие показатели в Январе, Апреле и Августе. В различные времена года спрос на недвижимость может меняться из-за сезонных факторов. Например, в Январе люди могут активнее искать квартиры из-за начала нового года, планирования перемещений или в связи с возможностью получения налоговых вычетов. Август может быть периодом повышенного спроса из-за начала нового учебного года, когда многие семьи ищут жилье для детей, поступающих в учебные заведения. В Июне спрос может быть ниже из-за начала летних каникул и сезона отпусков, когда многие сосредотачиваются на отдыхе, а не на покупке недвижимости.
#
#
# + Цены за квадратный метр падали с 2014ого и были самыми низкими в 2016ом году, и до 2019ого их рост не останавливался. Это обсулволенно тем, что 2014-2016 годах Россия столкнулась с экономическим кризисом, вызванным падением цен на нефть и санкциями. Это привело к снижению покупательной способности населения, что, в свою очередь, сказалось на рынке недвижимости. Падение спроса привело к снижению цен. Затем экономика России начала постепенное восстановление. Улучшение экономической ситуации могло привести к росту спроса на недвижимость, что в свою очередь могло повысить цены.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Исходя из расчетов выводы верны, но не забудь, пожалуйста, их перепроверить после корректировки.
# </div>

# %% [markdown]
# **Вывод v1.1**
#
# Что заметно на графиках:
# + Цена квартир выставленных на продажу в течении рабочей недели выше, чем на выходных. Особенно в среду. Это может быть связано тем, что продавцы могут быть более активны в размещении объявлений и организации показов квартир. Это может повышать видимость объявлений и привлекать больше покупателей, что в свою очередь может повлиять на цены. Некоторые продавцы могут специально выбирать рабочие дни для выставления своих квартир на продажу, чтобы привлечь больше внимания и получить лучшие предложения.
#
#
# + Ниже всего цены на квартиры становятся в Июне, а самые высокие показатели в Январе, Апреле и Августе. В различные времена года спрос на недвижимость может меняться из-за сезонных факторов. Например, в Январе люди могут активнее искать квартиры из-за начала нового года, планирования перемещений или в связи с возможностью получения налоговых вычетов. Август может быть периодом повышенного спроса из-за начала нового учебного года, когда многие семьи ищут жилье для детей, поступающих в учебные заведения. В Июне спрос может быть ниже из-за начала летних каникул и сезона отпусков, когда многие сосредотачиваются на отдыхе, а не на покупке недвижимости.
#
#
# + Цены за квадратный метр падали с 2014ого и были самыми низкими в 2016ом году, и до 2019ого их рост не останавливался. Это обсулволенно тем, что 2014-2016 годах Россия столкнулась с экономическим кризисом, вызванным падением цен на нефть и санкциями. Это привело к снижению покупательной способности населения, что, в свою очередь, сказалось на рынке недвижимости. Падение спроса привело к снижению цен. Затем экономика России начала постепенное восстановление. Улучшение экономической ситуации могло привести к росту спроса на недвижимость, что в свою очередь могло повысить цены.

# %% [markdown]
# #### Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений

# %% [markdown]
# ##### Постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов.

# %%
locality_pivot_table = data.pivot_table(index = 'locality_name', values = 'price_per_sq_m', aggfunc=['count', 'mean'])
locality_pivot_table.columns = ['count', 'mean']
locality_pivot_table = locality_pivot_table.sort_values('mean', ascending = False).head(10)

print (locality_pivot_table)

locality_pivot_table.plot(kind='bar', y='mean', figsize=(10, 6))
plt.title('Цена за квадратный метр в 10 населённых пунктах с наибольшим числом объявлений')
plt.xlabel('Населённый пункт')
plt.ylabel('Средняя цена за квадратный метр')
plt.xticks(rotation=45, ha='right')  # Поворот подписей по оси x на 45 градусов для лучшей читаемости
plt.grid(axis='y')
plt.show()
# Out:
#                    count           mean
# locality_name
# Санкт-Петербург    14847  114878.793628
# поселок Репино         3  108075.666667
# Зеленогорск           23  106043.347826
# Пушкин               353  103467.623229
# Сестрорецк           167  101232.233533
# поселок Левашово       1   96997.000000
# деревня Кудрово      428   95149.873832
# деревня Мистолово     10   93098.400000
# поселок Парголово    291   90568.773196
# поселок Стрельна      44   88691.477273

# %% [markdown]
# ##### Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
#самая высокая стоимость
locality_pivot_table[locality_pivot_table['mean']==locality_pivot_table['mean'].max()]
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  14847  114878.793628

# %%
#самая низкая стоимость
locality_pivot_table[locality_pivot_table['mean']==locality_pivot_table['mean'].min()]
# Out:
#                   count          mean
# locality_name
# поселок Стрельна     44  88691.477273

# %% [markdown]
# **Вывод**
#
# Выбрав десять населенных пунктов с наибольшим числом объявлений, можно сделать вывод, что самая дорогая недвижимость находится в СПБ, а самая дешевая (из 10 выбранных населенных пунктов) в Выборге.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Таблица верна. Совет: на общие продажи лучше смотреть через призму медианы. Она более устойчива к выбросам.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Также хорошо бы визуализировать получаемую информацию.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Отлично, но хорошо бы применить сортировку
# </div>

# %% [markdown]
# Применил сортировку по mean

# %% [markdown]
# #### Выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра. Учитывайте каждый километр расстояния: узнайте среднюю цену квартир в одном километре от центра, в двух и так далее. Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.

# %% [markdown]
# ##### Выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра.

# %% [markdown]
# Выделим отдельно срез по СПБ

# %%
data_spb = data.query('locality_name == "Санкт-Петербург"')
data_spb.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
# 7             5     7915000        71.6           2019-04-18      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 2             NaN             5         34.3      4         False  ...
# 3            3.00            14          NaN      9         False  ...
# 4            3.03            14         32.0     13         False  ...
# 7             NaN            24          NaN     22         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  ceiling_hight_vs_center  \
# ...

# %% [markdown]
# ##### Учитывайте каждый километр расстояния: узнайте среднюю цену квартир в одном километре от центра, в двух и так далее.

# %%
pivot_table_spb = data_spb.pivot_table(index = 'citycenters_nearest_km', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_spb.columns = ['mean', 'count', 'median']

pivot_table_spb
# Out:
#                                    mean  count      median
# citycenters_nearest_km
# 0.0                     32351004.923077     26  22450000.0
# 1.0                     21391721.075676    185  11490000.0
# 2.0                      17823691.79661    295   9900000.0
# 3.0                     11110597.442771    332   8400000.0
# 4.0                     13387316.013616    661   9100000.0
# 5.0                     14537855.649083    872   9495000.0
# 6.0                     15360717.734375    576   8988706.5
# 7.0                        14890864.205    400   7800000.0
# 8.0                     10080911.339254    563   7500000.0
# 9.0                      6971415.135624    553   5301000.0
# 10.0                     6508043.654919    681   5050000.0
# 11.0                      6287701.02957   1116   5100000.0
# 12.0                     5852066.487196   1523   4990000.0
# 13.0                     6078813.308973   1382   5200600.0
# ...

# %% [markdown]
# ##### Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.

# %%
pivot_table_spb.plot(y = 'median')
# Out:
# <AxesSubplot:xlabel='citycenters_nearest_km'>

# %% [markdown]
# **Вывод**
#
# На графике видны два падения цены. Первое падение в районе 1 км от центра и в районе 8-9 км о центра. Если говорить о центре, то логичнее всего сказать о том, что центром можно считать то, что находится в переделах 8-9км.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# А зависит ли цена от удаления от центра?
# </div>

# %% [markdown]
# С удалением от центра цена квартиры заметно падает, снова возрастая, на удалении 20 и 27 км от центра. Скорее всего там находятся какие-то "элитные" коттеджные поселки.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# В данном проекте был проведен первичный анализ данных, для которого были выведены первые строки, использован метод `info()`, построены гистограммы. Первичный анализ показал множество столбцов с пропущенными значениями. В последствии пропуски были заполнены везде, где было возможно. Там где требовалось, были установленны корректные типы данных. Список проделанной работы:
# + balcony - заменили пропущенные значения на 0;
# + cityCenters_nearest - приведен к змеиному языку;
# + locality_name - заполнены пропуски, значения приведены к общей структуре;
# + ceiling_height- заполнены пропуски;
# + floors_total- заполнены пропуски;
# + last_price - переведено к int;
# + is_apartment - заполнены пропуски;
# + first_day_exposition - переведено к datetime.
#
# Далее следовала обработка неявных дубликатов. Неявные дубликаты были обнаружены в столбце `'locality_name'`. Они были заменены с помощью метода `.replace`.
# Было установлено, что большинство квартир продаются во временном диапазоне от 41 дня до 252 дней, и быстрой продажей можно считать квартиры проданные до 41 дня после времени размещения.
# Изучено влияние различных параметров на стоимость квадратного метра недвижимости. Было продемонстрировано, что такие параметры как общая площадь, жилая площадь и площадь кухни имеют незначительное влияние на стоимость квадратного метра жилья. Больше всего на стоимость влияют такие параметры как количество комнат, тип этажа, на котором расположена квартира (первый, последний, другой) и дата размещения (день недели, месяц, год). Например, дешевле всего обошлась бы 1комнатная квартира в 24-ех км. от Питера, если бы объявление было выложенно в выходные в Июне 2016ого.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами. Но, не забудь, пожалуйста, их перепроверить после корректировок.
#
# Ты очень серьезно подходишь к визуализации.
#
# Вот пара ссылок на полезные источники:
#
# * [Как строить красивые графики на Python с Seaborn](https://habr.com/ru/companies/otus/articles/540526/)
#
# * [Seaborn для визуализации данных в Python](https://pythonru.com/biblioteki/seaborn-plot)
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Антон, замечательная работа, ты мыслишь нестандартно, это отличный навык, который у тебя уже есть, ты последователен и вдумчив. Твою работу очень интересно читать и проверять.  Я оставил несколько обязательных поправок для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
# Антон, спасибо, что прислал работу на повторное ревью. По проекту у нас осталось только дооформить графики, а также вывести один параметр в исследовательской части. Прошу тебя дополнить проект и прислать на проверку.

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.3</b>
#
# 👋
#
# Антон, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [x]  Найдены пропущенные значения.
# - [x]  Пропущенные значения заполнены там, где это возможно.
# - [x]  Объяснено, какие пропущенные значения обнаружены.
# - [x]  В каждом столбце установлен корректный тип данных.
# - [x]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [x]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [x]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [x]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [x]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [x]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [x]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [x]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [x]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [x]  На каждом этапе сделаны промежуточные выводы.
# - [x]  В конце проекта сделан общий вывод.
